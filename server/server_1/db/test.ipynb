# %%
from manager import DBManager
from datetime import datetime

# %%
# !export AWS_ACCESS_KEY_ID=AKIAWVHPEBTIFJBFIAVQ
# !export AWS_SECRET_ACCESS_KEY=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

# %%
# manager 생성
db = DBManager("mongodb+srv://boostcampaitech8_team10_db:PPrbBsm29xEzsc4o@cluster0.x0ilxtb.mongodb.net/?appName=Cluster0")

# %%
print("DBManager created successfully.")
print(db.count_documents())  # 컬렉션의 문서 개수 출력
print(db.get_all_client_status())

print(db.get_client_status("client_1"))
# Out:
# DBManager created successfully.
# 5
# [{'_id': ObjectId('6977347c5ad7523dd5630240'), 'client_id': 'client_1', 'status': False, 'updated_at': datetime.datetime(2026, 1, 26, 9, 37, 16, 659000)}]
# {'_id': ObjectId('6977347c5ad7523dd5630240'), 'client_id': 'client_1', 'status': False, 'updated_at': datetime.datetime(2026, 1, 26, 9, 37, 16, 659000)}

# %%
images = db.load_images(all_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 images = db.load_images(all_data)
#
# NameError: name 'all_data' is not defined

# %%
print(images)
from PIL import Image
print(images[0])
images[0].show()  # 첫 번째 이미지 표시
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7BA831B43BC0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7BA831B43C80>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7BA83E5A9340>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7BA83E9CB290>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7BA8330E1370>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7BA83E98A660>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7BA83E9E2DB0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7BA854DB7DA0>]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7BA831B43BC0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360>

# %%
db.close()
